# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Standard vectors
i = np.array([1,0])
j = np.array([0,1])

# these two vector now mapped to arbitrary vectors
vi = np.array([3,0])
vj = np.array([1,3])

# origin
origin = np.zeros(2)

# scaled by 2
si = 2*vi
sj = 2*vj

# %% [markdown]
# # Plotting into 2D
# #

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.quiver(*origin, *i, color='k', angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *j, color='r', angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *vi, color='k', angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *vj, color='r',angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *si, color='g',angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *sj, color='y',angles='xy', scale_units='xy', scale=1)


# figure
ax.grid()
ax.set_xlim(-8,8)
ax.set_ylim(-8,8)
ax.set_aspect('equal')

# text
ax.text(i[0], i[1], s='i', color='r')
ax.text(j[0], j[1], s='j', color='k')


plt.show()

# %% [markdown]
# # Calculates  Eigenvalues and Eigenvectors
#
# (A - kI)x = 0
#
# x != 0
#
# so, for non-zero vector, a matrix must be singular
#
# det(A-kI) = 0
#
# A -> Given matrix
#
# k -> scalar
#
# I -> Identity matrix
#
# x -> non-zero vector

# %%
A = np.array([[4,2],[1,3]])
origin = np.zeros(A.shape)
eigen_val, eigen_vec = np.linalg.eig(A)
print(f"Eigenvalue of A = {eigen_val}")
print(f"Eigenvector of A =\n {eigen_vec}")
# Out:
# Eigenvalue of A = [5. 2.]
# Eigenvector of A =
#  [[ 0.89442719 -0.70710678]
#  [ 0.4472136   0.70710678]]

# %%
fig,ax = plt.subplots(figsize=(8,6))

ax.quiver(*origin, *eigen_vec, angles="xy", scale_units='xy', scale=1)

ax.grid()
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# # Collinear/Collinearity and Codirected/Codirection
# Collinear -> Two-vectors are collinear if vectors points in the same line or the opposite direction.
#
# Codirection -> Two vectors that points in the same line.

# %%
# Two-vectors
v1 = np.array([2,3])
v2 = np.array([4,6]) #this vector in same line

#this vector flip opposite direction
vi = np.array([2,3])
vj = np.array([-4,-6])

origin = np.zeros(2)

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.quiver(*origin, *v1, color='k', angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *v2, color='r', angles='xy', scale_units='xy', scale=1)

# axes lines
ax.axhline(0, color='k')
ax.axvline(0, color='k')

# figure
ax.grid()
ax.set_xlim(-8,8)
ax.set_ylim(-8,8)
ax.set_xlabel('y')
ax.set_ylabel('x')
ax.set_aspect('equal')

# text
ax.text(v1[0], v1[1], s='v1', color='k')
ax.text(v2[0], v2[1], s='v2', color='r')
ax.text(v2[0], 0.5*v2[1], s='Collinear\n and Codirection', color='k')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.quiver(*origin, *vi, color='b', angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *vj, color='y', angles='xy', scale_units='xy', scale=1)



# axes lines
ax.axhline(0, color='k')
ax.axvline(0, color='k')

# figure
ax.grid()
ax.set_xlim(-8,8)
ax.set_ylim(-8,8)
ax.set_xlabel('y')
ax.set_ylabel('x')
ax.set_aspect('equal')

# text
# 
ax.text(vi[0], vi[1], s='vi', color='k')
ax.text(vj[0], vj[1], s='vj', color='r')
ax.text(vi[0], 2*vi[1], s='Collinear', color='k')

plt.show()

# %%
x = np.linspace(1,-1, 30)
y = np.linspace(1,-1, 30)
x,y = np.meshgrid(x,y)

A = np.zeros((2,2))
theta = np.pi/4


A[0,0] = -np.cos(theta)
A[0,1] = np.sin(theta)
A[1,0] = np.sin(theta)
A[1,1] = np.cos(theta)

m = A[0,0]*x + A[0,1]*y
n = A[1,0]*x + A[1,1]*y

# %%
fig,ax = plt.subplots(figsize=(6,6))

ax.grid()
ax.axhline(0, color='k')
ax.axvline(0, color='k')

ax.scatter(m,n, c=y)

plt.show()

# %% [markdown]
# # Eigendecomposition
# It diagonalized the matrices, off diagonal are zero values. Diagonal matrix powers are trivial.
#
# Mathematically, A = Q Λ Q^−1
#
# simplifiction above formula: Λ = Q.A.Q^-1  -> this gives diagonal matrix
#
# Q -> Eigenvectors as columns
#
# Λ -> Eigenvalues on diagonal
#
# Q^-1 -> Inverse of Q

# %% [markdown]
# # For 2D

# %%
# matrix = np.array([[2,4],[3,1]]) #original matrix
matrix = np.random.randint(1,10, size=((2,2)))

# Standard basis vector(x) to representing the co-ordinate system
# x = np.array([[1,0],[0,1]])
x = np.eye(2)
Ax = matrix @ x

# Eigendecompositon of a square matrix A
eig_val,Q = np.linalg.eig(matrix)
eig_val = np.diag(eig_val)
inv_Q = np.linalg.inv(Q)
A = Q @ eig_val @ inv_Q

# Diagoanl matrix power

# Diagonalization of A
D = inv_Q @ (np.linalg.matrix_power(A,4)) @ Q

print(f"Transformed of basis =\n {Ax}")
print(f"Diagonalized of matrix =\n {np.round(D)}")
print(f"Eigenvector of matrix =\n {Q}")
print(f"Eigenvalue of matrix =\n {np.round(eig_val)}")
print(f"Inverse of Q =\n {inv_Q}")
print(f"Eigendecomposition of matrix =\n {A}")
# Out:
# Transformed of basis =
#  [[3. 6.]
#  [1. 2.]]
# Diagonalized of matrix =
#  [[625.   0.]
#  [  0.  -0.]]
# Eigenvector of matrix =
#  [[ 0.9486833  -0.89442719]
#  [ 0.31622777  0.4472136 ]]
# Eigenvalue of matrix =
#  [[5. 0.]
#  [0. 0.]]
# Inverse of Q =
#  [[ 0.63245553  1.26491106]
#  [-0.4472136   1.34164079]]
# Eigendecomposition of matrix =
#  [[3. 6.]
#  [1. 2.]]

# %%
origin = np.zeros(A.shape)
fig,ax = plt.subplots(figsize=(8,6))

ax.quiver(*origin, *x, color='r', angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *Ax, color='g', angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *Q, color='b', angles='xy', scale_units='xy', scale=1)

ax.axhline(color='k')
ax.axvline(color='k')

ax.grid()
ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
ax.set_aspect("equal")

plt.show()

# %% [markdown]
# # For 3D

# %%
matrix = np.random.randint(1,10, size=((3,3)))
# transforms -> standard basis vector
x = np.eye(3)
Ax = matrix @ x

# Eigendecompositon of a square matrix A
eig_val,Q = np.linalg.eig(matrix)
eig_val = np.diag(eig_val)
inv_Q = np.linalg.inv(Q)
A = Q @ eig_val @ inv_Q

# Diagoanl matrix power
# A_100 = Q @ np.linalg.matrix_power(eig_val, 20) @ inv_Q 

# Diagonalization of A
D = inv_Q @ (np.linalg.matrix_power(A,2)) @ Q

print(f"Transformed of basis =\n {Ax}")
print(f"Diagonalized of matrix =\n {np.round(D,4)}")
print(f"Eigenvector of matrix =\n {Q}")
print(f"Eigenvalue of matrix =\n {np.round(eig_val,2)}")
print(f"Inverse of Q =\n {inv_Q}")
print(f"Eigendecomposition of matrix  =\n {A}")
# Out:
# Transformed of basis =
#  [[4. 3. 3.]
#  [2. 5. 5.]
#  [7. 4. 7.]]
# Diagonalized of matrix =
#  [[ 1.843124e+02+0.j     -0.000000e+00+0.j     -0.000000e+00-0.j    ]
#  [ 0.000000e+00-0.j     -1.562000e-01+3.0897j  0.000000e+00+0.j    ]
#  [ 0.000000e+00-0.j      0.000000e+00-0.j     -1.562000e-01-3.0897j]]
# Eigenvector of matrix =
#  [[ 0.4001992 +0.j          0.0304384 +0.3624913j   0.0304384 -0.3624913j ]
#  [ 0.52943435+0.j         -0.70193888+0.j         -0.70193888-0.j        ]
#  [ 0.74802398+0.j          0.51962537-0.32395193j  0.51962537+0.32395193j]]
# Eigenvalue of matrix =
#  [[13.58+0.j    0.  +0.j    0.  +0.j  ]
#  [ 0.  +0.j    1.21+1.27j  0.  +0.j  ]
#  [ 0.  +0.j    0.  +0.j    1.21-1.27j]]
# Inverse of Q =
#  [[ 0.58867787+1.48420781e-16j  0.5131518 +0.00000000e+00j
#    0.6587107 -3.71051952e-17j]
#  [ 0.22200386-1.03574446e+00j -0.51879147+2.39703103e-01j
#    0.24841484+3.84475702e-01j]
#  [ 0.22200386+1.03574446e+00j -0.51879147-2.39703103e-01j
#    0.24841484-3.84475702e-01j]]
# Eigendecomposition of matrix  =
#  [[4.+8.61776538e-16j 3.+1.25279500e-17j 3.-2.18290763e-16j]
#  [2.+1.33739746e-15j 5.-1.87265030e-16j 5.-2.43450328e-16j]
#  [7.+1.30412049e-15j 4.+1.15254827e-16j 7.-3.95057499e-16j]]

# %%
origin = np.zeros(A.shape)
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(projection='3d')

ax.quiver(*origin, *x, color='r')
ax.quiver(*origin, *Ax, color='g')
ax.quiver(*origin, *Q, color='b')

ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
ax.set_zlim(-10,10)

ax.set_box_aspect([1,1,1])

plt.show()
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:3305: ComplexWarning: Casting complex values to real discards the imaginary part
#   UVW = np.column_stack(input_args[3:]).astype(float)

# %% [markdown]
# # Power Iteration
# This is usually use for finding eigenvalue for large matrices.
#
# Steps are:
#
# 1) Starts with any random vector
# 2) Repeatedly multiply by matrix A (v -> Ax -> A^2x ->.....-> A^nv)
# 3) Normalization keeps the vector from overflow
# 4) The vector converges to the fixed direction(dominant eigenvector)

# %%
A = np.array([[2,1],[1,2]])
eig_val,eig_vec = np.linalg.eig(A)
x = np.array([3,4])

# for _ in range(20):
#     x = A@x/np.linalg.norm(A@x)
#     print(x)

# x

# %%
origin = np.zeros(A.shape)
fig,ax = plt.subplots(figsize=(6,5))

ax.quiver(*origin, *eig_vec, angles='xy', scale_units='xy', scale=1)
ax.quiver(*origin, *x, angles='xy', scale_units='xy', scale=1)

ax.grid()
ax.set_xlim(-5,5)
ax.set_ylim(-5,5)
ax.set_aspect('equal')

plt.show()
