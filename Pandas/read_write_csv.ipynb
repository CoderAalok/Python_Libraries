# %%
import pandas as pd
import csv
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
data = pd.read_csv('names.csv')
data[:5].set_index('email')
# Out:
#                           first_name       last_name
# email
# john-doe@bogusemail.com         John             Doe
# maryjacobs@bogusemail.com       Mary  Smith-Robinson
# davesmith@bogusemail.com        Dave           Smith
# janestuart@bogusemail.com       Jane          Stuart
# tomwright@bogusemail.com         Tom          Wright

# %% [markdown]
# # csv file makes in format  using csv module

# %%
file = 'names.csv'
with open(file) as csv_file:
    read_file = csv.reader(csv_file)
    
    with open('format_data.csv', 'w')as f_data:
        write_file = csv.writer(f_data, delimiter='\t')
        
        for data in read_file:
            write_file.writerow(data)

# %% [markdown]
# # Using DictReader to make format csv file

# %%
file = 'names.csv'
with open(file) as csv_file:
    read_file = csv.DictReader(csv_file)
    
    with open('format_data.csv', 'w')as f_data:
        col_names = ['first_name', 'last_name', 'email']
        write_file = csv.DictWriter(f_data, fieldnames=col_names, delimiter='\t')
        write_file.writeheader()
        
        for data in read_file:
            # del data['last_name']
            write_file.writerow(data)

# %%
data_m = pd.read_csv('museum_visitors.csv', index_col='Date')
data_m.head()
# print(data_m)
data_m.loc[:,'Avila Adobe']
data_m.loc[:, 'America Tropical Interpretive Center']
# Out:
# Date
# 2014-01-01     6602
# 2014-02-01     5029
# 2014-03-01     8129
# 2014-04-01     2824
# 2014-05-01    10694
# 2014-06-01    11036
# 2014-07-01    13490
# 2014-08-01     9139
# 2014-09-01     5661
# 2014-10-01     7356
# 2014-11-01     9773
# 2014-12-01     7184
# 2015-01-01     6250
# 2015-02-01     5907
# 2015-03-01     9884
# 2015-04-01     7254
# 2015-05-01    13207
# 2015-06-01    11102
# 2015-07-01    11072
# 2015-08-01    12096
# 2015-09-01     6608
# 2015-10-01    12524
# 2015-11-01     6677
# 2015-12-01     5967
# 2016-01-01     6587
# 2016-02-01     6955
# 2016-03-01     9979
# 2016-04-01     5113
# 2016-05-01     7757
# 2016-06-01     6751
# 2016-07-01    12188
# 2016-08-01     6245
# 2016-09-01     6977
# 2016-10-01     6282
# 2016-11-01     6365
# 2016-12-01     5223
# 2017-01-01     4929
# 2017-02-01     4493
# 2017-03-01     6271
# 2017-04-01     6685
# 2017-05-01     7556
# 2017-06-01     6818
# 2017-07-01     8675
# 2017-08-01     6212
# 2017-09-01     4607
# ...

# %%
plt.figure(figsize=(12,6))
ax = sb.lineplot(data=data_m)
ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=10)) # Adjust nbins to change the number of ticks
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
ax = sb.lineplot(data=data_m['America Tropical Interpretive Center'], label='America Tropical Interpretive Center', color='green', marker='o')
ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=10))
plt.xticks(rotation=0)
plt.show()

# %%
df = pd.DataFrame([[3,1,4],[3,1,4]], index=[1,2])
df.apply(lambda x: x**4)
# Out:
#     0  1    2
# 1  81  1  256
# 2  81  1  256
