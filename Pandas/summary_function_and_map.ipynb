# %%
import numpy as np
import pandas as pd

# %%
reviews = pd.read_csv('ramen-ratings.csv')
reviews.head(5)
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Extract all unique countries
reviews['Country'].unique()

stars = reviews['Stars'].head(20)

# %% [markdown]
# # DataFrame Countries and Stars

# %%
stars = reviews['Stars'].head(10)
countries = reviews['Country'].head(10)
cups = reviews['Style'].head(10)

df = pd.DataFrame({'Stars':stars, 'Country':countries, "Cup":cups}, index=list(np.arange(1, 10)))

# %%
reviews_points = reviews['Review #'].mean()
res = reviews['Review #'].map(lambda x: x - reviews_points)
# reviews['Stars'].describe()

# reviews['Country'].describe()
print(res)

# mean = sum of total no. of elements / no. of elements
sum(reviews['Review #'] / len(reviews['Review #']))
# Out:
# 0       1289.5
# 1       1288.5
# 2       1287.5
# 3       1286.5
# 4       1285.5
#          ...
# 2575   -1285.5
# 2576   -1286.5
# 2577   -1287.5
# 2578   -1288.5
# 2579   -1289.5
# Name: Review #, Length: 2580, dtype: float64
# 1290.5000000000005

# %%
def highest_review(rew):
    return rew > 500

reviews['Review #'].apply(highest_review)

# data = pd.DataFrame({'Stocks':[100, 421, 40], 'Prices':[420000, 1000, 233300,]})
# data.apply(highest_review, axis=0)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2575    False
# 2576    False
# 2577    False
# 2578    False
# 2579    False
# Name: Review #, Length: 2580, dtype: bool
