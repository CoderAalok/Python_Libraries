# %%
import numpy as np

# %% [markdown]
# # re-shape

# %%
matrix = np.arange(100).reshape((5,10,2))
print(matrix)

# matrix[-1,:, ...][6:-1, 6:-1] = 0
# print(matrix[0])

([np.array([v]) for mx in matrix[0] for v in mx if (v>10 and v <=60) and (v%2 == 0)])

# print(matrix[0][0])
# print(matrix[-1][-1,:,...][0])
# print(matrix[np.any(matrix>990 )])

s,r,c = matrix.shape
print(f"Size: {s}\nRow: {r}\nColumn: {c}")

# %%
# 
matrix1 = np.random.randint(5, size=((3,3)))
print(matrix1)
# this return m*n matrix full matrix elements like 2
print(np.full_like(matrix1, 0))

# %%
a = np.arange(1,10).reshape(3,3)
x = np.sum(a)
